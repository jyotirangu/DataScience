# %% [markdown]
# ## **Questions based on Titanic Dataset:**
#
# To read the dataset as csv, use the below code:
#
# ```python
# import pandas as pd
#
# url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv"
# titanic_df = pd.read_csv(url)
# ```

# %%
import pandas as pd
import numpy as np

# %%
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv"
titanic_df = pd.read_csv(url)

# %% [markdown]
# ### `Q-1:` Using `groupby` make groups using the `"Pclass"` column and find out the average age and total number of missing values in the `"Age"` column for every group.

# %%
pclass_groups = titanic_df.groupby("Pclass")
for group in list(pclass_groups.groups.keys()):
    print(f"Pclass {group} : Avg Age {pclass_groups.get_group(group)['Age'].mean()}and total missing value {pclass_groups.get_group(group)['Age'].isna().sum()}")
# Out:
# Pclass 1 : Avg Age 38.233440860215055and total missing value 30
# Pclass 2 : Avg Age 29.87763005780347and total missing value 11
# Pclass 3 : Avg Age 25.14061971830986and total missing value 136

# %% [markdown]
# ### `Q-2:` Using `groupby` make groups using the `"Pclass"` column and fill every group's `"Embarked"` column's missing values with the mode value of that group. After that, print every group's `"Embarked"` column's value counts in ascending order.

# %%
for group in list(pclass_groups.groups.keys()):
    mode = pclass_groups.get_group(group)['Embarked'].mode()
    pclass_groups.get_group(group)['Embarked'].fillna(mode)
    print(pclass_groups.get_group(group)['Embarked'].value_counts(ascending =True))
# Out:
# Embarked
# Q      2
# C     85
# S    127
# Name: count, dtype: int64
# Embarked
# Q      3
# C     17
# S    164
# Name: count, dtype: int64
# Embarked
# C     66
# Q     72
# S    353
# Name: count, dtype: int64

# %% [markdown]
# ### `Q-3:` Make groups based on `"Embarked"` column. And for each of this embarked group, make another group based on `"Pclass"` and find out the average fare (round off up to 2 decimal places) for each "Pclass" for each group of "Embarked".
#
# **Sample Output:**
#
# ```bash
# {'C': {1: 105, 2: 25, 3: 11},
#  'Q': {1: 90, 2: 12, 3: 11},
#  'S': {1: 70, 2: 20, 3: 15}}
# ```

# %%
my_dict = {}

embarked_groups = titanic_df.groupby("Embarked")
for embarked_group in list(embarked_groups.groups.keys()):
    pclass_groups = embarked_groups.get_group(embarked_group).groupby('Pclass')
    my_dict[embarked_group] = {}
    for pclass_group in list(pclass_groups.groups.keys()):
        my_dict[embarked_group][pclass_group] = round(pclass_groups.get_group(pclass_group)["Fare"].mean(), 2)

my_dict
# Out:
# {'C': {1: np.float64(104.72), 2: np.float64(25.36), 3: np.float64(11.21)},
#  'Q': {1: np.float64(90.0), 2: np.float64(12.35), 3: np.float64(11.18)},
#  'S': {1: np.float64(70.36), 2: np.float64(20.33), 3: np.float64(14.64)}}

# %% [markdown]
# ## **Questions Based on Fifa Worldcup - 2022 Dataset:**
#
# You can read the dataset by using the below sample code
#
# ```python
# import pandas as pd
#
# fifa_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv")
# ```

# %%
import pandas as pd

fifa_df = pd.read_csv("8Fifa Worldcup 2022 - Sheet1.csv")

# %% [markdown]
# ### `Q-4:` Perform `groupby` based on the `"Team"` column and then perform Z Normalization on top of the below columns of each group:
# 1. Passes
# 2. Passes Completed
# 3. Attempted Line Breaks
# 4. Completed Line Breaks
#
# You have to make a python function named `z_normalization` which takes two arguments:
#
# 1. *group:* Every group that you have created
# 2. *cols_to_perform:* This parameter takes a list of columns on which you have to perform the Z-Normalization.
#
# For this problem, you have to use th `apply()` method.
#
# $\Large Z \ - \ Normalization = \frac{X_i - \mu}{std} $
#
# After that find out the below values for each group:
# - minimum "Passess"
# - maximum "Passess"
# - minimum "Yellow Cards"
# - maximum "Yellow cards"
# - average "Yellow Cards"
# - maximum "Attempted Line Breaks"
# - minimum "Attempted Line Breaks"
# - standardard deviation of "Attempted Line Breaks"
# - average Possession

# %%
def z_normalization(group, cols_to_perform):
    for col in cols_to_perform:
        std = group[col].std()
        mean = group[col].mean()
        group[f"{col}_z_norm"] = (group[col] - mean)/std
    return group

# %%
cols_to_perform = ["Passes","Passes Completed","Attempted Line Breaks","Completed Line Breaks"]
groups = fifa_df.groupby("Team")

# Apply z-normalization and reset index to avoid ambiguity
normalized_df = groups.apply(z_normalization, cols_to_perform=cols_to_perform).reset_index(drop=True)

# Now you can safely group again
groups = normalized_df.groupby("Team")
# Out:
# C:\Users\H\AppData\Local\Temp\ipykernel_34824\3275215864.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   normalized_df = groups.apply(z_normalization, cols_to_perform=cols_to_perform).reset_index(drop=True)

# %%
groups.agg(
    {
        "Passes": ["min","max"],
        "Yellow Cards":["min", "max", "mean"],
        "Attempted Line Breaks": ["max","min","std"],
        "Possession (%)": "mean"    
    }
)
# Out:
#                Passes       Yellow Cards               Attempted Line Breaks  \
#                   min   max          min max      mean                   max
# Team
# Argentina         408   862            0   8  2.285714                   249
# Australia         286   466            0   3  1.750000                   171
# Belgium           512   685            1   3  1.666667                   195
# Brazil            548   695            0   3  1.200000                   193
# Cameroon          295   500            1   5  2.666667                   182
# Canada            448   536            2   4  2.666667                   176
# Costa Rica        231   454            1   3  2.000000                   154
# Croatia           461   724            0   2  1.142857                   259
# Denmark           537   650            1   2  1.666667                   241
# Ecuador           429   484            0   2  1.000000                   177
# England           508   810            0   1  0.200000                   208
# France            358   734            0   3  1.142857                   179
# Germany           352   827            0   3  1.000000                   256
# Ghana             319   460            2   4  2.666667                   188
# Iran              232   463            2   3  2.333333                   195
# Japan             225   591            0   3  1.500000                   253
# Korea Republic    359   548            1   2  1.500000                   201
# Mexico            356   500            1   4  2.333333                   198
# Morocco           229   583            0   3  1.285714                   157
# Netherlands       403   786            0   4  1.800000                   198
# Poland            303   466            1   3  1.750000                   156
# Portugal          461   678            0   3  1.200000                   197
# Qatar             424   457            0   4  2.333333                   174
# Saudi Arabia      267   560            2   6  4.666667                   205
# Senegal           277   511            1   3  1.750000                   184
# Serbia            403   513            2   7  4.000000                   184
# Spain             647  1070            0   1  0.500000                   237
# Switzerland       403   512            1   4  2.250000                   178
# Tunisia           328   501            1   3  1.666667                   200
# United States     427   572            0   4  1.250000                   204
# Uruguay           390   528            1   3  2.000000                   186
# Wales             325   508            1   2  1.666667                   208
#
#                                Possession (%)
#                 min        std           mean
# Team
# Argentina       141  38.774685      49.285714
# Australia       133  17.682383      31.250000
# Belgium         167  14.422205      49.000000
# Brazil          164  10.691118      50.400000
# Cameroon        144  19.857828      38.333333
# Canada          102  37.753587      44.333333
# Costa Rica       86  38.974351      27.333333
# Croatia          97  54.499891      47.428571
# Denmark         173  34.000000      51.333333
# Ecuador         143  17.009801      42.666667
# England         133  29.676590      57.200000
# France          126  21.407609      44.857143
# Germany         143  56.624494      53.000000
# Ghana           122  33.020196      37.000000
# Iran             56  77.526340      31.666667
# Japan           104  64.048810      30.250000
# Korea Republic  139  27.072434      42.250000
# Mexico          127  40.706265      46.666667
# Morocco         128  10.641339      34.285714
# Netherlands     168  12.759310      44.000000
# Poland           79  36.326070      32.000000
# Portugal        165  13.049904      53.800000
# Qatar           159   7.767453      39.333333
# Saudi Arabia    147  29.022979      36.666667
# Senegal         143  16.938615      38.500000
# Serbia          140  22.188586      42.666667
# Spain           186  24.289916      67.000000
# Switzerland     157   9.032349      43.000000
# Tunisia         153  24.419937      38.666667
# United States   143  27.693260      47.000000
# Uruguay         146  22.030282      41.000000
# Wales           104  53.028294      41.000000

# %% [markdown]
# ## **Questions on IPL wala dataset**
#
# ball by ball dataset - https://drive.google.com/file/d/1-kvv_9KCSAFWcrhS9WgTxSrURkRh6GNt/view?usp=share_link

# %%
balls = pd.read_csv("8ipl_deliveries.csv")

# %% [markdown]
# ### `Q-5:` Find batsman in below category-
# * Highest score while chasing
# * Best Strike rate while chasing and have faced 100+ balls
#
#
# > Chasing mean team batting in second inning

# %%
df = balls[balls.innings==2]
df.groupby(["ID","batter"]).sum()
# Out:
#                                                                    Team  \
# ID      batter
# 335982  AA Noffke     Royal Challengers BangaloreKolkata Knight Ride...
#         B Akhil       Royal Challengers BangaloreKolkata Knight Ride...
#         CL White      Royal Challengers BangaloreKolkata Knight Ride...
#         JH Kallis     Royal Challengers BangaloreKolkata Knight Ride...
#         MV Boucher    Royal Challengers BangaloreKolkata Knight Ride...
# ...                                                                 ...
# 1312200 DA Miller     Rajasthan RoyalsGujarat TitansRajasthan Royals...
#         HH Pandya     Rajasthan RoyalsGujarat TitansRajasthan Royals...
#         MS Wade       Rajasthan RoyalsGujarat TitansRajasthan Royals...
#         Shubman Gill  Rajasthan RoyalsGujarat TitansRajasthan Royals...
#         WP Saha       Rajasthan RoyalsGujarat TitansRajasthan Royals...
#
#                       innings  overs  ballnumber  \
# ID      batter
# 335982  AA Noffke          24    110          43
#         B Akhil             4     16           3
#         CL White           20     64          42
#         JH Kallis          14     24          23
#         MV Boucher         22     66          54
# ...                       ...    ...         ...
# 1312200 DA Miller          40    299          81
#         HH Pandya          64    267         121
#         MS Wade            22     31          44
#         Shubman Gill       86    362         146
#         WP Saha            14      4          16
#
#                                                                  bowler  \
# ID      batter
# 335982  AA Noffke     AB AgarkarAB AgarkarAB AgarkarAB AgarkarSC Gan...
#         B Akhil                                    AB AgarkarAB Agarkar
#         CL White      AB AgarkarAB DindaAB AgarkarAB AgarkarAB Agark...
#         JH Kallis     AB DindaI SharmaI SharmaAB AgarkarAB AgarkarAB...
#         MV Boucher    AB DindaAB DindaAB DindaAB AgarkarAB AgarkarAB...
# ...                                                                 ...
# 1312200 DA Miller     YS ChahalYS ChahalYS ChahalYS ChahalOC McCoyOC...
#         HH Pandya     TA BoultTA BoultTA BoultTA BoultTA BoultYS Cha...
#         MS Wade       M Prasidh KrishnaM Prasidh KrishnaM Prasidh Kr...
#         Shubman Gill  TA BoultTA BoultTA BoultTA BoultTA BoultTA Bou...
#         WP Saha       TA BoultTA BoultTA BoultM Prasidh KrishnaM Pra...
#
#                                                             non-striker  \
# ID      batter
# 335982  AA Noffke     CL WhiteCL WhiteCL WhiteCL WhiteP KumarP Kumar...
#         B Akhil                                        CL WhiteCL White
#         CL White      W JafferMV BoucherMV BoucherMV BoucherMV Bouch...
#         JH Kallis     W JafferW JafferW JafferW JafferW JafferW Jaff...
#         MV Boucher    CL WhiteCL WhiteCL WhiteCL WhiteCL WhiteCL Whi...
# ...                                                                 ...
# 1312200 DA Miller     Shubman GillShubman GillShubman GillShubman Gi...
#         HH Pandya     Shubman GillShubman GillShubman GillShubman Gi...
#         MS Wade       Shubman GillShubman GillShubman GillShubman Gi...
#         Shubman Gill  WP SahaWP SahaWP SahaMS WadeMS WadeMS WadeMS W...
#         WP Saha       Shubman GillShubman GillShubman GillShubman Gi...
#
#                              extra_type  batsman_run  extras_run  total_run  \
# ID      batter
# 335982  AA Noffke            wideswides            9           2         11
#         B Akhil                       0            0           0          0
#         CL White                      0            6           0          6
#         JH Kallis               legbyes            8           1          9
#         MV Boucher    wideswideslegbyes            7           3         10
# ...                                 ...          ...         ...        ...
# 1312200 DA Miller                 wides           32           1         33
#         HH Pandya            wideswides           34           2         36
#         MS Wade                   wides            8           5         13
#         Shubman Gill            legbyes           45           1         46
#         WP Saha                       0            5           0          5
#
#                       non_boundary  isWicketDelivery  player_out     kind  \
# ID      batter
# 335982  AA Noffke                0                 1   AA Noffke  run out
#         B Akhil                  0                 1     B Akhil   caught
#         CL White                 0                 1    CL White   caught
#         JH Kallis                0                 1   JH Kallis   caught
#         MV Boucher               0                 1  MV Boucher   caught
# ...                            ...               ...         ...      ...
# 1312200 DA Miller                0                 0           0        0
#         HH Pandya                0                 1   HH Pandya   caught
#         MS Wade                  0                 1     MS Wade   caught
#         Shubman Gill             0                 0           0        0
#         WP Saha                  0                 1     WP Saha   bowled
#
#                      fielders_involved  \
# ID      batter
# 335982  AA Noffke           AB Agarkar
#         B Akhil             RT Ponting
#         CL White               WP Saha
#         JH Kallis             M Kartik
#         MV Boucher            M Kartik
# ...                                ...
# 1312200 DA Miller                    0
#         HH Pandya          YBK Jaiswal
#         MS Wade                R Parag
#         Shubman Gill                 0
#         WP Saha                      0
#
#                                                             BattingTeam  \
# ID      batter
# 335982  AA Noffke     Royal Challengers BangaloreRoyal Challengers B...
#         B Akhil       Royal Challengers BangaloreRoyal Challengers B...
#         CL White      Royal Challengers BangaloreRoyal Challengers B...
#         JH Kallis     Royal Challengers BangaloreRoyal Challengers B...
#         MV Boucher    Royal Challengers BangaloreRoyal Challengers B...
# ...                                                                 ...
# 1312200 DA Miller     Gujarat TitansGujarat TitansGujarat TitansGuja...
#         HH Pandya     Gujarat TitansGujarat TitansGujarat TitansGuja...
#         MS Wade       Gujarat TitansGujarat TitansGujarat TitansGuja...
#         Shubman Gill  Gujarat TitansGujarat TitansGujarat TitansGuja...
#         WP Saha       Gujarat TitansGujarat TitansGujarat TitansGuja...
#
#                                                             BowlingTeam
# ID      batter
# 335982  AA Noffke     Kolkata Knight RidersKolkata Knight RidersKolk...
#         B Akhil              Kolkata Knight RidersKolkata Knight Riders
#         CL White      Kolkata Knight RidersKolkata Knight RidersKolk...
#         JH Kallis     Kolkata Knight RidersKolkata Knight RidersKolk...
#         MV Boucher    Kolkata Knight RidersKolkata Knight RidersKolk...
# ...                                                                 ...
# 1312200 DA Miller     Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
#         HH Pandya     Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
#         MS Wade       Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
#         Shubman Gill  Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
#         WP Saha       Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
#
# [6972 rows x 17 columns]

# %%
df.groupby(["ID","batter"]).sum().sort_values(by = 'batsman_run',ascending = False)
# Out:
#                                                                     Team  \
# ID      batter
# 501206  PC Valthaty    Kings XI PunjabChennai Super KingsKings XI Pun...
# 501243  V Sehwag       Deccan ChargersDelhi DaredevilsDeccan Chargers...
# 1254061 SV Samson      Punjab KingsRajasthan RoyalsPunjab KingsRajast...
# 1136620 SR Watson      Sunrisers HyderabadChennai Super KingsSunriser...
# 336018  ST Jayasuriya  Mumbai IndiansChennai Super KingsMumbai Indian...
# ...                                                                  ...
# 501221  DE Bollinger                   Mumbai IndiansChennai Super Kings
# 501220  LRPL Taylor    Kings XI PunjabRajasthan RoyalsKings XI Punjab...
# 501221  R Ashwin       Mumbai IndiansChennai Super KingsMumbai Indian...
# 1304112 VR Iyer        Lucknow Super GiantsKolkata Knight RidersLuckn...
#         UT Yadav               Lucknow Super GiantsKolkata Knight Riders
#
#                        innings  overs  ballnumber  \
# ID      batter
# 501206  PC Valthaty        128    587         233
# 501243  V Sehwag           116    489         220
# 1254061 SV Samson          132    661         254
# 1136620 SR Watson          120    504         231
# 336018  ST Jayasuriya      106    306         209
# ...                        ...    ...         ...
# 501221  DE Bollinger         2     18           6
# 501220  LRPL Taylor         10     34          24
# 501221  R Ashwin             4     34           7
# 1304112 VR Iyer              8      0          10
#         UT Yadav             2     19           6
#
#                                                                   bowler  \
# ID      batter
# 501206  PC Valthaty    R AshwinR AshwinR AshwinTG SoutheeTG SoutheeTG...
# 501243  V Sehwag       DW SteynI SharmaI SharmaI SharmaI SharmaI Shar...
# 1254061 SV Samson      Mohammed ShamiMohammed ShamiMohammed ShamiMoha...
# 1136620 SR Watson      B KumarB KumarB KumarB KumarB KumarB KumarSand...
# 336018  ST Jayasuriya  MS GonyMS GonyMS GonyJA MorkelJA MorkelJA Mork...
# ...                                                                  ...
# 501221  DE Bollinger                                          SL Malinga
# 501220  LRPL Taylor          P KumarPP ChawlaPP ChawlaPP ChawlaPP Chawla
# 501221  R Ashwin                          Harbhajan SinghHarbhajan Singh
# 1304112 VR Iyer             Mohsin KhanMohsin KhanMohsin KhanMohsin Khan
#         UT Yadav                                              MP Stoinis
#
#                                                              non-striker  \
# ID      batter
# 501206  PC Valthaty    AC GilchristAC GilchristAC GilchristAC Gilchri...
# 501243  V Sehwag       NV OjhaNV OjhaNV OjhaNV OjhaNV OjhaNV OjhaNV O...
# 1254061 SV Samson      M VohraM VohraM VohraM VohraM VohraM VohraM Vo...
# 1136620 SR Watson      F du PlessisF du PlessisF du PlessisF du Pless...
# 336018  ST Jayasuriya  SR TendulkarSR TendulkarSR TendulkarSR Tendulk...
# ...                                                                  ...
# 501221  DE Bollinger                                         S Badrinath
# 501220  LRPL Taylor        STR BinnySTR BinnySTR BinnySTR BinnySTR Binny
# 501221  R Ashwin                                  S BadrinathS Badrinath
# 1304112 VR Iyer                             A TomarA TomarA TomarA Tomar
#         UT Yadav                                               SP Narine
#
#                                                            extra_type  \
# ID      batter
# 501206  PC Valthaty                                             wides
# 501243  V Sehwag                                    noballswideswides
# 1254061 SV Samson                       noballslegbyeswideswideswides
# 1136620 SR Watson                              wideslegbyeswideswides
# 336018  ST Jayasuriya  wideslegbyeswideswideslegbyeswideswideslegbyes
# ...                                                               ...
# 501221  DE Bollinger                                                0
# 501220  LRPL Taylor                                                 0
# 501221  R Ashwin                                                    0
# 1304112 VR Iyer                                                     0
#         UT Yadav                                                    0
#
#                        batsman_run  extras_run  total_run  non_boundary  \
# ID      batter
# 501206  PC Valthaty            120           1        121             0
# 501243  V Sehwag               119           3        122             0
# 1254061 SV Samson              119           5        124             0
# 1136620 SR Watson              117           4        121             0
# 336018  ST Jayasuriya          114           8        122             0
# ...                            ...         ...        ...           ...
# 501221  DE Bollinger             0           0          0             0
# 501220  LRPL Taylor              0           0          0             0
# 501221  R Ashwin                 0           0          0             0
# 1304112 VR Iyer                  0           0          0             0
#         UT Yadav                 0           0          0             0
#
#                        isWicketDelivery   player_out    kind  \
# ID      batter
# 501206  PC Valthaty                   0            0       0
# 501243  V Sehwag                      1     V Sehwag  caught
# 1254061 SV Samson                     1    SV Samson  caught
# 1136620 SR Watson                     0            0       0
# 336018  ST Jayasuriya                 0            0       0
# ...                                 ...          ...     ...
# 501221  DE Bollinger                  0            0       0
# 501220  LRPL Taylor                   1  LRPL Taylor     lbw
# 501221  R Ashwin                      1     R Ashwin  caught
# 1304112 VR Iyer                       1      VR Iyer  caught
#         UT Yadav                      1     UT Yadav  bowled
#
#                       fielders_involved  \
# ID      batter
# 501206  PC Valthaty                   0
# 501243  V Sehwag          KC Sangakkara
# 1254061 SV Samson              DJ Hooda
# 1136620 SR Watson                     0
# 336018  ST Jayasuriya                 0
# ...                                 ...
# 501221  DE Bollinger                  0
# 501220  LRPL Taylor                   0
# 501221  R Ashwin             KA Pollard
# 1304112 VR Iyer               Q de Kock
#         UT Yadav                      0
#
#                                                              BattingTeam  \
# ID      batter
# 501206  PC Valthaty    Kings XI PunjabKings XI PunjabKings XI PunjabK...
# 501243  V Sehwag       Delhi DaredevilsDelhi DaredevilsDelhi Daredevi...
# 1254061 SV Samson      Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
# 1136620 SR Watson      Chennai Super KingsChennai Super KingsChennai ...
# 336018  ST Jayasuriya  Mumbai IndiansMumbai IndiansMumbai IndiansMumb...
# ...                                                                  ...
# 501221  DE Bollinger                                 Chennai Super Kings
# 501220  LRPL Taylor    Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
# 501221  R Ashwin                  Chennai Super KingsChennai Super Kings
# 1304112 VR Iyer        Kolkata Knight RidersKolkata Knight RidersKolk...
#         UT Yadav                                   Kolkata Knight Riders
#
#                                                              BowlingTeam
# ID      batter
# 501206  PC Valthaty    Chennai Super KingsChennai Super KingsChennai ...
# 501243  V Sehwag       Deccan ChargersDeccan ChargersDeccan ChargersD...
# 1254061 SV Samson      Punjab KingsPunjab KingsPunjab KingsPunjab Kin...
# 1136620 SR Watson      Sunrisers HyderabadSunrisers HyderabadSunriser...
# 336018  ST Jayasuriya  Chennai Super KingsChennai Super KingsChennai ...
# ...                                                                  ...
# 501221  DE Bollinger                                      Mumbai Indians
# 501220  LRPL Taylor    Kings XI PunjabKings XI PunjabKings XI PunjabK...
# 501221  R Ashwin                            Mumbai IndiansMumbai Indians
# 1304112 VR Iyer        Lucknow Super GiantsLucknow Super GiantsLuckno...
#         UT Yadav                                    Lucknow Super Giants
#
# [6972 rows x 17 columns]

# %%
df.groupby(["ID","batter"]).sum().sort_values(by = 'batsman_run',ascending = False)['batsman_run'].head()
# Out:
# ID       batter
# 501206   PC Valthaty      120
# 501243   V Sehwag         119
# 1254061  SV Samson        119
# 1136620  SR Watson        117
# 336018   ST Jayasuriya    114
# Name: batsman_run, dtype: int64

# %%
temp_df = df[~(df.extra_type == "wides")].copy()
# Group to get total runs and balls
agg_df = temp_df.groupby('batter').agg(
    batsman_run=('batsman_run', 'sum'),
    ballnumber=('ballnumber', 'count')
)
# Calculate strike rate
agg_df['strike_rate'] = agg_df['batsman_run'] / agg_df['ballnumber'] * 100

# Filter for players with at least 100 balls and sort by strike rate
result_df = agg_df[agg_df['ballnumber'] >= 100].sort_values('strike_rate', ascending=False).reset_index()

result_df.head()
# Out:
#            batter  batsman_run  ballnumber  strike_rate
# 0      PJ Cummins          222         114   194.736842
# 1      AD Russell          986         570   172.982456
# 2  LS Livingstone          182         107   170.093458
# 3       SP Narine          599         356   168.258427
# 4      SO Hetmyer          330         200   165.000000

# %% [markdown]
# ### `Q-6` Most Successful bowler against any batsman. Find that pair of bowler and batsman.
# > Most Successful in terms of dissmissal. A bowler who have dissmissed any batsman most no of times. If any two pairs have same no of dissmisal, consider runs conceded by bowler to that batsman. Those who have concede lesser runs is more successful.

# %%
balls["IsBatterOut"] = balls.batter == balls.player_out
balls.groupby(['bowler', 'batter']).agg(
    {
        "IsBatterOut": "sum",
        "batsman_run":"sum"
    }
).sort_values(by=["IsBatterOut","batsman_run"],ascending=[False,True]).head()
# Out:
#                            IsBatterOut  batsman_run
# bowler         batter
# Z Khan         MS Dhoni              7           74
# Sandeep Sharma V Kohli               7           78
# A Mishra       RG Sharma             7           87
# R Ashwin       RV Uthappa            7          123
# SP Narine      RG Sharma             7          137

# %% [markdown]
# ### `Q-7`: Most successful batting pair in IPL. Batting pair who have scored most runs playing together.

# %%
def func(x):
    return '-'.join(list(np.sort(x.values)))

# %%
balls["batter-pair"] = balls[["batter","non-striker"]].apply(func, axis=1)
balls.groupby('batter-pair')["total_run"].sum().sort_values(ascending = False).head()
# Out:
# batter-pair
# AB de Villiers-V Kohli    3134
# CH Gayle-V Kohli          2802
# DA Warner-S Dhawan        2357
# G Gambhir-RV Uthappa      1906
# KL Rahul-MA Agarwal       1731
# Name: total_run, dtype: int64

# %% [markdown]
# ### `Q-8:` Make a dataframe for all batting pairs played together.
# ```
# Batsman1 Batsman2 Runs Avg StrikeRate
# ```
#
# > Just to ease this question you can count wide-balls for strike rate.

# %%
temp_df = balls.groupby('batter-pair').agg(
    {
        "total_run":"sum",
        "ballnumber" : "count",
        "isWicketDelivery": "sum"
    }
).reset_index()
temp_df["Batsman 1"] = temp_df["batter-pair"].apply(lambda x:x.split("-")[0])
temp_df["Batsman 2"] = temp_df["batter-pair"].apply(lambda x:x.split("-")[1])
temp_df.rename(columns = {"total_run": "Runs"}, inplace = True)
temp_df["StrikeRate"] = temp_df["Runs"]/ temp_df["ballnumber"] * 100
temp_df["Avg"] = temp_df["Runs"] / temp_df["isWicketDelivery"]
temp_df.sort_values("Runs", ascending = False, inplace = True)
temp_df[["Batsman 1", "Batsman 2", "Runs", "Avg", "StrikeRate"]]
# Out:
#            Batsman 1    Batsman 2  Runs        Avg  StrikeRate
# 302   AB de Villiers      V Kohli  3134  44.140845  152.209811
# 1251        CH Gayle      V Kohli  2802  52.867925  142.017233
# 1508       DA Warner     S Dhawan  2357  48.102041  136.637681
# 1954       G Gambhir   RV Uthappa  1906  39.708333  133.754386
# 2803        KL Rahul   MA Agarwal  1731  52.454545  142.939719
# ...              ...          ...   ...        ...         ...
# 34       A Choudhary     S Badree     0   0.000000    0.000000
# 4215        T Stubbs  Tilak Varma     0   0.000000    0.000000
# 64          A Mishra     CL White     0   0.000000    0.000000
# 3114  M Muralitharan      MS Gony     0   0.000000    0.000000
# 3107        M Morkel     S Nadeem     0   0.000000    0.000000
#
# [4259 rows x 5 columns]
