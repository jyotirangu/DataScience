# %%
import pandas as pd

# %% [markdown]
# `Q-1:` You are given a Multi index DataFrame. You task is to swap level-0 index with level-0 column.
# * Change Branch -> ('cse', 'ece') as columns at level-0 and ('delhi'	'mumbai') as level-0 Index
# * And Sort on row index level-0

# %%
# Given Code Snippets
index_val = [('cse',2019),('cse',2020),('cse',2021),('cse',2022),('ece',2019),('ece',2020),('ece',2021),('ece',2022)]
multiindex = pd.MultiIndex.from_tuples(index_val)
df = pd.DataFrame(
    [
        [1,2,0,0],
        [3,4,0,0],
        [5,6,0,0],
        [7,8,0,0],
        [9,10,0,0],
        [11,12,0,0],
        [13,14,0,0],
        [15,16,0,0],
    ],
    index = multiindex,
    columns = pd.MultiIndex.from_product([['delhi','mumbai'],['avg_package','students']])
)

df
# Out:
#                delhi               mumbai
#          avg_package students avg_package students
# cse 2019           1        2           0        0
#     2020           3        4           0        0
#     2021           5        6           0        0
#     2022           7        8           0        0
# ece 2019           9       10           0        0
#     2020          11       12           0        0
#     2021          13       14           0        0
#     2022          15       16           0        0

# %%
df.unstack()
# Out:
#           delhi                                             mumbai            \
#     avg_package                students                avg_package
#            2019 2020 2021 2022     2019 2020 2021 2022        2019 2020 2021
# cse           1    3    5    7        2    4    6    8           0    0    0
# ece           9   11   13   15       10   12   14   16           0    0    0
#
#
#          students
#     2022     2019 2020 2021 2022
# cse    0        0    0    0    0
# ece    0        0    0    0    0

# %%
df.unstack(level=0)
# Out:
#            delhi                       mumbai
#      avg_package     students     avg_package     students
#              cse ece      cse ece         cse ece      cse ece
# 2019           1   9        2  10           0   0        0   0
# 2020           3  11        4  12           0   0        0   0
# 2021           5  13        6  14           0   0        0   0
# 2022           7  15        8  16           0   0        0   0

# %%
df.unstack(level=0).stack()
# Out:
# C:\Users\H\AppData\Local\Temp\ipykernel_18276\267232932.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.unstack(level=0).stack()
#                delhi               mumbai
#          avg_package students avg_package students
# 2019 cse           1        2           0        0
#      ece           9       10           0        0
# 2020 cse           3        4           0        0
#      ece          11       12           0        0
# 2021 cse           5        6           0        0
#      ece          13       14           0        0
# 2022 cse           7        8           0        0
#      ece          15       16           0        0

# %%
df.unstack(level=0).stack(level=0)
# Out:
# C:\Users\H\AppData\Local\Temp\ipykernel_18276\268355546.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.unstack(level=0).stack(level=0)
#             avg_package     students
#                     cse ece      cse ece
# 2019 delhi            1   9        2  10
#      mumbai           0   0        0   0
# 2020 delhi            3  11        4  12
#      mumbai           0   0        0   0
# 2021 delhi            5  13        6  14
#      mumbai           0   0        0   0
# 2022 delhi            7  15        8  16
#      mumbai           0   0        0   0

# %%
df.unstack(level=0).stack(level=0).swaplevel()
# Out:
# C:\Users\H\AppData\Local\Temp\ipykernel_18276\2458699195.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.unstack(level=0).stack(level=0).swaplevel()
#             avg_package     students
#                     cse ece      cse ece
# delhi  2019           1   9        2  10
# mumbai 2019           0   0        0   0
# delhi  2020           3  11        4  12
# mumbai 2020           0   0        0   0
# delhi  2021           5  13        6  14
# mumbai 2021           0   0        0   0
# delhi  2022           7  15        8  16
# mumbai 2022           0   0        0   0

# %%
df.unstack(level=0).stack(level=0).swaplevel().swaplevel(axis=1)
# Out:
# C:\Users\H\AppData\Local\Temp\ipykernel_18276\2244893037.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.unstack(level=0).stack(level=0).swaplevel().swaplevel(axis=1)
#                     cse         ece      cse      ece
#             avg_package avg_package students students
# delhi  2019           1           9        2       10
# mumbai 2019           0           0        0        0
# delhi  2020           3          11        4       12
# mumbai 2020           0           0        0        0
# delhi  2021           5          13        6       14
# mumbai 2021           0           0        0        0
# delhi  2022           7          15        8       16
# mumbai 2022           0           0        0        0

# %%
df.unstack(level=0).stack(level=0).swaplevel().swaplevel(axis=1).sort_index()
# Out:
# C:\Users\H\AppData\Local\Temp\ipykernel_18276\1833749936.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.unstack(level=0).stack(level=0).swaplevel().swaplevel(axis=1).sort_index()
#                     cse         ece      cse      ece
#             avg_package avg_package students students
# delhi  2019           1           9        2       10
#        2020           3          11        4       12
#        2021           5          13        6       14
#        2022           7          15        8       16
# mumbai 2019           0           0        0        0
#        2020           0           0        0        0
#        2021           0           0        0        0
#        2022           0           0        0        0

# %% [markdown]
# `Q-2:` Covid Cases Data Set Problem
#  Make a DataFrame Using both Covid Dataset. With Country name as Level-0 and Provinance/State as Level-1 Index and date, No of cases and No of Deaths as Columns.

# %%
confirm = pd.read_csv('1time_series_covid19_confirmed_global.csv')
deaths = pd.read_csv('1time_series_covid19_deaths_global.csv')

# %%
confirm.head(2)
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  12/24/22  12/25/22  12/26/22  \
# 0        0        0        0        0  ...    207310    207399    207438
# 1        0        0        0        0  ...    333749    333749    333751
#
#    12/27/22  12/28/22  12/29/22  12/30/22  12/31/22  1/1/23  1/2/23
# 0    207460    207493    207511    207550    207559  207616  207627
# 1    333751    333776    333776    333806    333806  333811  333812
#
# [2 rows x 1081 columns]

# %%
deaths.head(2)
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  12/24/22  12/25/22  12/26/22  \
# 0        0        0        0        0  ...      7845      7846      7846
# 1        0        0        0        0  ...      3595      3595      3595
#
#    12/27/22  12/28/22  12/29/22  12/30/22  12/31/22  1/1/23  1/2/23
# 0      7846      7846      7847      7847      7849    7849    7849
# 1      3595      3595      3595      3595      3595    3595    3595
#
# [2 rows x 1081 columns]

# %%
deaths = deaths.melt(id_vars=['Province/State','Country/Region','Lat','Long'], var_name='date',value_name='num_deaths')
deaths
# Out:
#        Province/State        Country/Region        Lat        Long     date  \
# 0                 NaN           Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN               Albania  41.153300   20.168300  1/22/20
# 2                 NaN               Algeria  28.033900    1.659600  1/22/20
# 3                 NaN               Andorra  42.506300    1.521800  1/22/20
# 4                 NaN                Angola -11.202700   17.873900  1/22/20
# ...               ...                   ...        ...         ...      ...
# 311248            NaN    West Bank and Gaza  31.952200   35.233200   1/2/23
# 311249            NaN  Winter Olympics 2022  39.904200  116.407400   1/2/23
# 311250            NaN                 Yemen  15.552727   48.516388   1/2/23
# 311251            NaN                Zambia -13.133897   27.849332   1/2/23
# 311252            NaN              Zimbabwe -19.015438   29.154857   1/2/23
#
#         num_deaths
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 311248        5708
# 311249           0
# 311250        2159
# 311251        4024
# 311252        5637
#
# [311253 rows x 6 columns]

# %%
confirm = confirm.melt(id_vars=['Province/State','Country/Region','Lat','Long'], var_name='date',value_name='num_case')
confirm
# Out:
#        Province/State        Country/Region        Lat        Long     date  \
# 0                 NaN           Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN               Albania  41.153300   20.168300  1/22/20
# 2                 NaN               Algeria  28.033900    1.659600  1/22/20
# 3                 NaN               Andorra  42.506300    1.521800  1/22/20
# 4                 NaN                Angola -11.202700   17.873900  1/22/20
# ...               ...                   ...        ...         ...      ...
# 311248            NaN    West Bank and Gaza  31.952200   35.233200   1/2/23
# 311249            NaN  Winter Olympics 2022  39.904200  116.407400   1/2/23
# 311250            NaN                 Yemen  15.552727   48.516388   1/2/23
# 311251            NaN                Zambia -13.133897   27.849332   1/2/23
# 311252            NaN              Zimbabwe -19.015438   29.154857   1/2/23
#
#         num_case
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 311248    703228
# 311249       535
# 311250     11945
# 311251    334661
# 311252    259981
#
# [311253 rows x 6 columns]

# %%
final_df = confirm.merge(deaths,on=['Province/State','Country/Region','Lat','Long','date'])

# %%
final_df.head(2)
# Out:
#   Province/State Country/Region       Lat       Long     date  num_case  \
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20         0
# 1            NaN        Albania  41.15330  20.168300  1/22/20         0
#
#    num_deaths
# 0           0
# 1           0

# %%
final_df.set_index(['Country/Region','Province/State'],inplace=True)
final_df
# Out:
#                                            Lat        Long     date  num_case  \
# Country/Region       Province/State
# Afghanistan          NaN             33.939110   67.709953  1/22/20         0
# Albania              NaN             41.153300   20.168300  1/22/20         0
# Algeria              NaN             28.033900    1.659600  1/22/20         0
# Andorra              NaN             42.506300    1.521800  1/22/20         0
# Angola               NaN            -11.202700   17.873900  1/22/20         0
# ...                                        ...         ...      ...       ...
# West Bank and Gaza   NaN             31.952200   35.233200   1/2/23    703228
# Winter Olympics 2022 NaN             39.904200  116.407400   1/2/23       535
# Yemen                NaN             15.552727   48.516388   1/2/23     11945
# Zambia               NaN            -13.133897   27.849332   1/2/23    334661
# Zimbabwe             NaN            -19.015438   29.154857   1/2/23    259981
#
#                                      num_deaths
# Country/Region       Province/State
# Afghanistan          NaN                      0
# Albania              NaN                      0
# Algeria              NaN                      0
# Andorra              NaN                      0
# Angola               NaN                      0
# ...                                         ...
# West Bank and Gaza   NaN                   5708
# Winter Olympics 2022 NaN                      0
# Yemen                NaN                   2159
# Zambia               NaN                   4024
# Zimbabwe             NaN                   5637
#
# [311253 rows x 5 columns]

# %%
final_df[['date','num_case','num_deaths']]
# Out:
#                                         date  num_case  num_deaths
# Country/Region       Province/State
# Afghanistan          NaN             1/22/20         0           0
# Albania              NaN             1/22/20         0           0
# Algeria              NaN             1/22/20         0           0
# Andorra              NaN             1/22/20         0           0
# Angola               NaN             1/22/20         0           0
# ...                                      ...       ...         ...
# West Bank and Gaza   NaN              1/2/23    703228        5708
# Winter Olympics 2022 NaN              1/2/23       535           0
# Yemen                NaN              1/2/23     11945        2159
# Zambia               NaN              1/2/23    334661        4024
# Zimbabwe             NaN              1/2/23    259981        5637
#
# [311253 rows x 3 columns]

# %% [markdown]
# `Q-3:` Show Country with Highest death percent out of confirmed Cases.

# %%
final_df
# Out:
#                                            Lat        Long     date  num_case  \
# Country/Region       Province/State
# Afghanistan          NaN             33.939110   67.709953  1/22/20         0
# Albania              NaN             41.153300   20.168300  1/22/20         0
# Algeria              NaN             28.033900    1.659600  1/22/20         0
# Andorra              NaN             42.506300    1.521800  1/22/20         0
# Angola               NaN            -11.202700   17.873900  1/22/20         0
# ...                                        ...         ...      ...       ...
# West Bank and Gaza   NaN             31.952200   35.233200   1/2/23    703228
# Winter Olympics 2022 NaN             39.904200  116.407400   1/2/23       535
# Yemen                NaN             15.552727   48.516388   1/2/23     11945
# Zambia               NaN            -13.133897   27.849332   1/2/23    334661
# Zimbabwe             NaN            -19.015438   29.154857   1/2/23    259981
#
#                                      num_deaths
# Country/Region       Province/State
# Afghanistan          NaN                      0
# Albania              NaN                      0
# Algeria              NaN                      0
# Andorra              NaN                      0
# Angola               NaN                      0
# ...                                         ...
# West Bank and Gaza   NaN                   5708
# Winter Olympics 2022 NaN                      0
# Yemen                NaN                   2159
# Zambia               NaN                   4024
# Zimbabwe             NaN                   5637
#
# [311253 rows x 5 columns]

# %%
final_df.index
# Out:
# MultiIndex([(         'Afghanistan',                            nan),
#             (             'Albania',                            nan),
#             (             'Algeria',                            nan),
#             (             'Andorra',                            nan),
#             (              'Angola',                            nan),
#             (          'Antarctica',                            nan),
#             ( 'Antigua and Barbuda',                            nan),
#             (           'Argentina',                            nan),
#             (             'Armenia',                            nan),
#             (           'Australia', 'Australian Capital Territory'),
#             ...
#             (             'Uruguay',                            nan),
#             (          'Uzbekistan',                            nan),
#             (             'Vanuatu',                            nan),
#             (           'Venezuela',                            nan),
#             (             'Vietnam',                            nan),
#             (  'West Bank and Gaza',                            nan),
#             ('Winter Olympics 2022',                            nan),
#             (               'Yemen',                            nan),
#             (              'Zambia',                            nan),
#             (            'Zimbabwe',                            nan)],
#            names=['Country/Region', 'Province/State'], length=311253)

# %%
final_df.index.get_level_values(0)
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antarctica',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'West Bank and Gaza', 'Winter Olympics 2022', 'Yemen', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name='Country/Region', length=311253)

# %%
final_df.index.get_level_values(0).unique()
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antarctica',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'West Bank and Gaza', 'Winter Olympics 2022', 'Yemen', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name='Country/Region', length=201)

# %%
final_df.groupby('Country/Region')
final_df.head(3)
# Out:
#                                     Lat       Long     date  num_case  \
# Country/Region Province/State
# Afghanistan    NaN             33.93911  67.709953  1/22/20         0
# Albania        NaN             41.15330  20.168300  1/22/20         0
# Algeria        NaN             28.03390   1.659600  1/22/20         0
#
#                                num_deaths
# Country/Region Province/State
# Afghanistan    NaN                      0
# Albania        NaN                      0
# Algeria        NaN                      0

# %%
temp_df = final_df.groupby('Country/Region').sum()[['num_case','num_deaths']]

# %%
temp_df['death_percentage'] = (temp_df['num_deaths']/temp_df['num_case'])*100

# %%
temp_df
# Out:
#                        num_case  num_deaths  death_percentage
# Country/Region
# Afghanistan           116218938     4901323          4.217319
# Albania               163505982     2248012          1.374881
# Algeria               164830894     4447129          2.697995
# Andorra                21390392      116300          0.543702
# Angola                 53083822     1104387          2.080459
# ...                         ...         ...               ...
# West Bank and Gaza    366130648     3377981          0.922616
# Winter Olympics 2022     179152           0          0.000000
# Yemen                   7091065     1372952         19.361718
# Zambia                173488194     2364727          1.363048
# Zimbabwe              123084606     3087612          2.508528
#
# [201 rows x 3 columns]

# %%
temp_df.sort_values('death_percentage',ascending=False)
# Out:
#                         num_case  num_deaths  death_percentage
# Country/Region
# Korea, North                 234        1404        600.000000
# MS Zaandam                  9071        2014         22.202624
# Yemen                    7091065     1372952         19.361718
# Sudan                   38729339     2850576          7.360250
# Peru                  2203724423   156296296          7.092370
# ...                          ...         ...               ...
# Antarctica                  4235           0          0.000000
# Holy See                   24893           0          0.000000
# Summer Olympics 2020      441598           0          0.000000
# Tuvalu                    137771           0          0.000000
# Winter Olympics 2022      179152           0          0.000000
#
# [201 rows x 3 columns]

# %% [markdown]
# `Q-4` : Make a dataframe for India from Covid Data with one extra column representing no of new cases.
#
# * Just for Assumption "No of new cases" will be equal to difference of "no of cases" with previous day.
# * First day new cases will be NaN or equal to no of cases
#
# Say on 12/30/22 No of cases is - 44679608	and a day previous (12/29/22) no of cases is - 44679382.
#
# Then for 12/30/22 -> No of New Cases  = 44679608 - 44679382 =
#
# Note:- Try using shift Function

# %% [markdown]
# Try using the shift function
#
# ```
# s = pd.Series([1,2,3,4,5,6])
# s #-> [1,2,3,4,5,6]
# s.shift(1) #-> [NaN, 1,2,3,4,5]
# s.shift(-1) #-> [2,3,4,5,6, NaN]
# ```

# %%
final_df
# Out:
#                                            Lat        Long     date  num_case  \
# Country/Region       Province/State
# Afghanistan          NaN             33.939110   67.709953  1/22/20         0
# Albania              NaN             41.153300   20.168300  1/22/20         0
# Algeria              NaN             28.033900    1.659600  1/22/20         0
# Andorra              NaN             42.506300    1.521800  1/22/20         0
# Angola               NaN            -11.202700   17.873900  1/22/20         0
# ...                                        ...         ...      ...       ...
# West Bank and Gaza   NaN             31.952200   35.233200   1/2/23    703228
# Winter Olympics 2022 NaN             39.904200  116.407400   1/2/23       535
# Yemen                NaN             15.552727   48.516388   1/2/23     11945
# Zambia               NaN            -13.133897   27.849332   1/2/23    334661
# Zimbabwe             NaN            -19.015438   29.154857   1/2/23    259981
#
#                                      num_deaths
# Country/Region       Province/State
# Afghanistan          NaN                      0
# Albania              NaN                      0
# Algeria              NaN                      0
# Andorra              NaN                      0
# Angola               NaN                      0
# ...                                         ...
# West Bank and Gaza   NaN                   5708
# Winter Olympics 2022 NaN                      0
# Yemen                NaN                   2159
# Zambia               NaN                   4024
# Zimbabwe             NaN                   5637
#
# [311253 rows x 5 columns]

# %%
india_df = final_df.loc['India'].copy()

# %%
india_df
# Out:
#                       Lat      Long      date  num_case  num_deaths
# Province/State
# NaN             20.593684  78.96288   1/22/20         0           0
# NaN             20.593684  78.96288   1/23/20         0           0
# NaN             20.593684  78.96288   1/24/20         0           0
# NaN             20.593684  78.96288   1/25/20         0           0
# NaN             20.593684  78.96288   1/26/20         0           0
# ...                   ...       ...       ...       ...         ...
# NaN             20.593684  78.96288  12/29/22  44679382      530699
# NaN             20.593684  78.96288  12/30/22  44679608      530702
# NaN             20.593684  78.96288  12/31/22  44679873      530705
# NaN             20.593684  78.96288    1/1/23  44680046      530707
# NaN             20.593684  78.96288    1/2/23  44680180      530707
#
# [1077 rows x 5 columns]

# %%
print(type(india_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
india_df['num_case']
# Out:
# Province/State
# NaN           0
# NaN           0
# NaN           0
# NaN           0
# NaN           0
#          ...
# NaN    44679382
# NaN    44679608
# NaN    44679873
# NaN    44680046
# NaN    44680180
# Name: num_case, Length: 1077, dtype: int64

# %%
india_df['num_case'].shift(1)
# Out:
# Province/State
# NaN           NaN
# NaN           0.0
# NaN           0.0
# NaN           0.0
# NaN           0.0
#           ...
# NaN    44679139.0
# NaN    44679382.0
# NaN    44679608.0
# NaN    44679873.0
# NaN    44680046.0
# Name: num_case, Length: 1077, dtype: float64

# %%
india_df['new_cases'] = india_df['num_case'] - india_df['num_case'].shift(1)

# %%
india_df
# Out:
#                       Lat      Long      date  num_case  num_deaths  new_cases
# Province/State
# NaN             20.593684  78.96288   1/22/20         0           0        NaN
# NaN             20.593684  78.96288   1/23/20         0           0        0.0
# NaN             20.593684  78.96288   1/24/20         0           0        0.0
# NaN             20.593684  78.96288   1/25/20         0           0        0.0
# NaN             20.593684  78.96288   1/26/20         0           0        0.0
# ...                   ...       ...       ...       ...         ...        ...
# NaN             20.593684  78.96288  12/29/22  44679382      530699      243.0
# NaN             20.593684  78.96288  12/30/22  44679608      530702      226.0
# NaN             20.593684  78.96288  12/31/22  44679873      530705      265.0
# NaN             20.593684  78.96288    1/1/23  44680046      530707      173.0
# NaN             20.593684  78.96288    1/2/23  44680180      530707      134.0
#
# [1077 rows x 6 columns]

# %% [markdown]
# `Q-5:` Read the Dataset using the below given link and create a multi-index dataframe using the columns "Country" and "City/Town".
#
# This dataset is about the most polluted cities in the world. You can get details from [here](https://www.kaggle.com/datasets/rajkumarpandey02/worlds-most-air-polluted-countries-cities).
#
# **Dataset link:** https://tinyurl.com/2fe6vz4u Directly use this link to read.
#
# **Task:**
# 1. Find out the name of the city of India which is most poluted based on PM10.
# 2. Find out the name of the city of India which has minumum pollution level based on PM10.
# 3. Do same operations (like 1 and 2) with the country China.
# 4. Make a pie chart based on the column "PM10" of the country Poland.
# 5. Make a bar chart based on the columns "PM2.5" and "PM10" of the countries Israel and Qatar.
# 6. Convert this MultiIndex DataFrame to Series by retaining the informations.

# %%
df = pd.read_csv('https://tinyurl.com/2fe6vz4u')
df.head()
# Out:
#    Unnamed: 0  Position Country  City/Town  Year  PM2.5 Temporal coverage  \
# 0           0         1   India     Kanpur  2016    173              >75%
# 1           1         2   India  Faridabad  2016    172              >75%
# 2           2         3   India       Gaya  2016    149        50% -< 75%
# 3           3         4   India   Varanasi  2016    146              >75%
# 4           4         5   India      Patna  2016    144              >75%
#
#    PM10 Temporal coverage.1  Database version (year)
# 0   319                 NaN                     2018
# 1   316                 NaN                     2018
# 2   275                 NaN                     2018
# 3   260                 NaN                     2018
# 4   266                 NaN                     2018

# %%
df.drop(columns = ['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#    Position Country  City/Town  Year  PM2.5 Temporal coverage  PM10  \
# 0         1   India     Kanpur  2016    173              >75%   319
# 1         2   India  Faridabad  2016    172              >75%   316
# 2         3   India       Gaya  2016    149        50% -< 75%   275
# 3         4   India   Varanasi  2016    146              >75%   260
# 4         5   India      Patna  2016    144              >75%   266
#
#   Temporal coverage.1  Database version (year)
# 0                 NaN                     2018
# 1                 NaN                     2018
# 2                 NaN                     2018
# 3                 NaN                     2018
# 4                 NaN                     2018

# %%
df.set_index(['Country','City/Town'],inplace=True)

# %%
df.head(5)
# Out:
#                    Position  Year  PM2.5 Temporal coverage  PM10  \
# Country City/Town
# India   Kanpur            1  2016    173              >75%   319
#         Faridabad         2  2016    172              >75%   316
#         Gaya              3  2016    149        50% -< 75%   275
#         Varanasi          4  2016    146              >75%   260
#         Patna             5  2016    144              >75%   266
#
#                   Temporal coverage.1  Database version (year)
# Country City/Town
# India   Kanpur                    NaN                     2018
#         Faridabad                 NaN                     2018
#         Gaya                      NaN                     2018
#         Varanasi                  NaN                     2018
#         Patna                     NaN                     2018

# %%
# 1

df.loc['India']
# Out:
#                     Position  Year  PM2.5 Temporal coverage  PM10  \
# City/Town
# Kanpur                     1  2016    173              >75%   319
# Faridabad                  2  2016    172              >75%   316
# Gaya                       3  2016    149        50% -< 75%   275
# Varanasi                   4  2016    146              >75%   260
# Patna                      5  2016    144              >75%   266
# Delhi                      6  2016    143              >75%   292
# Lucknow                    7  2016    138              >75%   255
# Agra                       9  2016    131              >75%   194
# Gurgaon                   10  2016    120        50% -< 75%   124
# Muzaffarpur               11  2016    120              >75%   221
# Jaipur                    14  2016    105        50% -< 75%   193
# Patiala                   16  2016    101               NaN   184
# Jodhpur                   17  2016     98              >75%   180
# Nagpur                    33  2016     84               NaN    86
# Kolkata                   55  2016     74              >75%   136
# Ahmedabad                 87  2015     65        50% -< 75%   120
# Mumbai                    94  2016     64              >75%   104
# Chandrapur               111  2016     60              >75%   109
# Panchkula                153  2016     55              >75%   101
# Pune                     189  2016     50              >75%    89
# Chennai                  202  2016     49              >75%    80
# Bangalore                239  2016     46              >75%    96
# Hyderabad                264  2016     44              >75%    84
# Navi Mumbai              290  2016     41               NaN    67
# Udaipur                  291  2016     41               NaN    98
# Guwahati                 295  2016     40               NaN    81
# Solapur                  306  2016     39              >75%    71
# Jabalpur                 316  2016     38               NaN    79
# Thiruvananthapuram       346  2016     35               NaN    48
# Vizag                    353  2016     34               NaN    76
# Tezpur                   366  2016     33               NaN    52
# Aizawl                   484  2016     27               NaN    44
#
#                    Temporal coverage.1  Database version (year)
# City/Town
# Kanpur                             NaN                     2018
# Faridabad                          NaN                     2018
# Gaya                               NaN                     2018
# Varanasi                           NaN                     2018
# Patna                              NaN                     2018
# Delhi                              NaN                     2018
# Lucknow                            NaN                     2018
# Agra                               NaN                     2018
# Gurgaon                            NaN                     2018
# Muzaffarpur                        NaN                     2018
# Jaipur                             NaN                     2018
# Patiala                            NaN                     2018
# Jodhpur                            NaN                     2018
# Nagpur                             NaN                     2018
# Kolkata                            NaN                     2018
# Ahmedabad                          NaN                     2018
# Mumbai                             NaN                     2018
# Chandrapur                         NaN                     2018
# Panchkula                          NaN                     2018
# Pune                               NaN                     2018
# Chennai                            NaN                     2018
# Bangalore                   50% -< 75%                     2018
# Hyderabad                          NaN                     2018
# Navi Mumbai                        NaN                     2018
# Udaipur                            NaN                     2018
# Guwahati                           NaN                     2018
# Solapur                            NaN                     2018
# Jabalpur                           NaN                     2018
# Thiruvananthapuram                 NaN                     2018
# Vizag                              NaN                     2018
# Tezpur                             NaN                     2018
# Aizawl                             NaN                     2018

# %%
df.loc['India'].sort_values('PM10',ascending=False).head()
# Out:
#            Position  Year  PM2.5 Temporal coverage  PM10 Temporal coverage.1  \
# City/Town
# Kanpur            1  2016    173              >75%   319                 NaN
# Faridabad         2  2016    172              >75%   316                 NaN
# Delhi             6  2016    143              >75%   292                 NaN
# Gaya              3  2016    149        50% -< 75%   275                 NaN
# Patna             5  2016    144              >75%   266                 NaN
#
#            Database version (year)
# City/Town
# Kanpur                        2018
# Faridabad                     2018
# Delhi                         2018
# Gaya                          2018
# Patna                         2018

# %%
df.loc['India'].sort_values('PM10',ascending=False).head(1).index[0]
# Out:
# 'Kanpur'

# %%
# 2

df.loc['India'].sort_values('PM10',ascending=False).tail(1).index[0]
# Out:
# 'Aizawl'

# %%
# 3

df.loc['China'].sort_values('PM10',ascending=False).tail(1).index[0]
# Out:
# 'Anshun'

# %%
df.loc['China'].sort_values('PM10',ascending=False).head(1).index[0]
# Out:
# 'Jinan'

# %%
# 4

df.loc['Poland']
# Out:
#                       Position  Year  PM2.5 Temporal coverage  PM10  \
# City/Town
# Godów                      371  2016     33              >75%    43
# Pleszew                    372  2016     33              >75%    38
# Gliwice                    393  2016     32              >75%    46
# Kraków                     405  2016     31              >75%    42
# Nowy Sącz                  406  2016     31              >75%    41
# Katowice                   426  2016     30              >75%    41
# Bochnia                    447  2016     29              >75%    35
# Piotrków Trybunalski       448  2016     29              >75%    38
# Żory                       449  2016     29              >75%    42
# Bielsko-Biała              472  2016     28              >75%    36
# Tarnowskie Góry            473  2016     28              >75%    38
# Chełm                      493  2015     27              >75%    35
# Kalisz                     494  2016     27              >75%    33
# Kędzierzyn-Koźle           495  2016     27              >75%    32
# Lublin                     496  2016     27              >75%    31
# Siedlce                    497  2016     27              >75%    29
# Trzebinia                  498  2016     27              >75%    35
#
#                      Temporal coverage.1  Database version (year)
# City/Town
# Godów                               >75%                     2018
# Pleszew                             >75%                     2018
# Gliwice                             >75%                     2018
# Kraków                              >75%                     2018
# Nowy Sącz                           >75%                     2018
# Katowice                            >75%                     2018
# Bochnia                             >75%                     2018
# Piotrków Trybunalski                >75%                     2018
# Żory                                >75%                     2018
# Bielsko-Biała                       >75%                     2018
# Tarnowskie Góry                     >75%                     2018
# Chełm                               >75%                     2018
# Kalisz                              >75%                     2018
# Kędzierzyn-Koźle                    >75%                     2018
# Lublin                              >75%                     2018
# Siedlce                             >75%                     2018
# Trzebinia                           >75%                     2018

# %%
df.loc['Poland']['PM10']
# Out:
# City/Town
# Godów                   43
# Pleszew                 38
# Gliwice                 46
# Kraków                  42
# Nowy Sącz               41
# Katowice                41
# Bochnia                 35
# Piotrków Trybunalski    38
# Żory                    42
# Bielsko-Biała           36
# Tarnowskie Góry         38
# Chełm                   35
# Kalisz                  33
# Kędzierzyn-Koźle        32
# Lublin                  31
# Siedlce                 29
# Trzebinia               35
# Name: PM10, dtype: int64

# %%
df.loc['Poland']['PM10'].plot(kind='pie')
# Out:
# <Axes: ylabel='PM10'>

# %%
df.loc['Poland']['PM10'].plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='PM10'>

# %%
# 5

df.loc[['Israel','Qatar']]
# Out:
#                    Position  Year  PM2.5 Temporal coverage  PM10  \
# Country City/Town
# Israel  Gvar'am         442  2015     29              >75%    69
#         Jerusalem       468  2015     28              >75%    66
#         Bnei Brak       487  2015     27              >75%    65
# Qatar   Doha             20  2012     93               NaN   168
#         Al Wakrah        30  2012     85               NaN   152
#
#                   Temporal coverage.1  Database version (year)
# Country City/Town
# Israel  Gvar'am                   NaN                     2018
#         Jerusalem                >75%                     2018
#         Bnei Brak                 NaN                     2018
# Qatar   Doha                      NaN                     2016
#         Al Wakrah                 NaN                     2016

# %%
df.loc[['Israel','Qatar']][['PM2.5','PM10']]
# Out:
#                    PM2.5  PM10
# Country City/Town
# Israel  Gvar'am       29    69
#         Jerusalem     28    66
#         Bnei Brak     27    65
# Qatar   Doha          93   168
#         Al Wakrah     85   152

# %%
df.loc[['Israel','Qatar']][['PM2.5','PM10']].plot(kind='bar')
# Out:
# <Axes: xlabel='Country,City/Town'>

# %%
# 6
df
# Out:
#                           Position  Year  PM2.5 Temporal coverage  PM10  \
# Country     City/Town
# India       Kanpur               1  2016    173              >75%   319
#             Faridabad            2  2016    172              >75%   316
#             Gaya                 3  2016    149        50% -< 75%   275
#             Varanasi             4  2016    146              >75%   260
#             Patna                5  2016    144              >75%   266
# ...                            ...   ...    ...               ...   ...
# Poland      Lublin             496  2016     27              >75%    31
#             Siedlce            497  2016     27              >75%    29
#             Trzebinia          498  2016     27              >75%    35
# El Salvador San Salvador       499  2016     27        50% -< 75%    59
# Turkey      Sivas              500  2016     27              >75%    56
#
#                          Temporal coverage.1  Database version (year)
# Country     City/Town
# India       Kanpur                       NaN                     2018
#             Faridabad                    NaN                     2018
#             Gaya                         NaN                     2018
#             Varanasi                     NaN                     2018
#             Patna                        NaN                     2018
# ...                                      ...                      ...
# Poland      Lublin                      >75%                     2018
#             Siedlce                     >75%                     2018
#             Trzebinia                   >75%                     2018
# El Salvador San Salvador                 NaN                     2018
# Turkey      Sivas                       >75%                     2018
#
# [500 rows x 7 columns]

# %%
df.stack()
# Out:
# Country  City/Town
# India    Kanpur     Position                      1
#                     Year                       2016
#                     PM2.5                       173
#                     Temporal coverage          >75%
#                     PM10                        319
#                                                ...
# Turkey   Sivas      PM2.5                        27
#                     Temporal coverage          >75%
#                     PM10                         56
#                     Temporal coverage.1        >75%
#                     Database version (year)    2018
# Length: 2638, dtype: object
